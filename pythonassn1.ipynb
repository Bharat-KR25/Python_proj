# %%
str1 = "Hello"
str2 = input("enter your name =")
str3 = (str1 + str2 + "Welcome to Python programming")
print (str1 + " " + str2 +" "+ "welcome to python programming")
# Out:
# enter your name = Bharat
# Hello Bharat welcome to python programming

# %%
# slicing
str3 = "Hello Bharat welcome to python programming"
print(str3[0])
print(str3[-1])
print(str3[0:5])
print(str3[0:11])
print(str3[ ::-1])
print(str3[-18:-12])
# Out:
# H
# g
# Hello
# Hello Bhara
# gnimmargorp nohtyp ot emoclew tarahB olleH
# python

# %%
strM = "Python beginner tutorial"
print(strM.upper())
print(strM.lower())
print(strM.capitalize())
print(strM.count('t'))
print(strM.replace("Python","Data Analytics"))
# Out:
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# 3
# Data Analytics beginner tutorial

# %%
tup1= (10, 20, 30)
tup2= (40, 50, 60)
t_combine = tup1 + tup2
print(t_combine)
tupe_comb= t_combine * 3
print(tupe_comb)
print(t_combine[:3])
print(t_combine[2])
print(t_combine[-3:])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# (10, 20, 30)
# 30
# (40, 50, 60)
