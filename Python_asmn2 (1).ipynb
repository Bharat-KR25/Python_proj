# %%
# 1.List Creation:
# a.Create a list named age_list with five integer elements. For eg., [24, 25, 27, 28 ,29]
# b.Create a list named name_list with five string elements.age_list = [24,25,27,28,29]
age_list = [24, 25, 27, 28, 29]
name_list = ["Ram", "Rita", "Ragavi", "Joshua"]
print(age_list)
print(name_list)

name_list.append("Yazhini") 
print (name_list)
print(age_list)
age_list.insert(2,26)
print(age_list)
name_list.remove("Yazhini")
print(name_list)
name_list.pop(3)
print(name_list)
age_list.extend([31,30,32])
print(age_list)
age_list.sort(reverse = True)

# Find the max age, min age, and sum of all ages from age_list.print(age_list)
print(max(age_list))
print(min(age_list))
print(sum(age_list))
# Print the first element of name_list.
# b. Print the last element of name_list.
# c. Print the elements from index 2 to index 4 in name_list.
# d. Print the elements of name_list in reverse order.
print(name_list[0])
print(name_list[-1])
print(name_list[2:4])
print(name_list[ ::-1])
#. Create a dictionary named student_marks that maps the names of five students to
# their marks (use a scale of 0 to 100).
#b. Access and print the mark of a specific student of your choice.
#c. Add a new student, "Janani," with a mark of 80 to the student_marks dictionary.
#d. Update the mark of any one older student to 82.
#e. Use the keys(), values(), and items() methods to print all keys, values, and key-value
# pairs in the student_marks dictionary.

students_marks = {"Ram": 80, "Vijay": 68, "Rohit": 76, "John": 79, "Gracy": 51}
print(students_marks)
print(students_marks["Vijay"])
students_marks.update({"Janani": 80})
print(students_marks)
students_marks["Rohit"] =78
print(students_marks)
students_marks.keys()
students_marks.values()
students_marks.items()

my_set={'a','e','i','o','u','a','a','i'}
# my_set[4] -- this throws an error bcs set are unordered and do not have a index position like list or a tuple.
# set1 with values: {1, 3, 5, 7, 9}
# set2 with values: {2, 3, 5, 8, 10}
set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}
print(set1)
print(set2)
set1. union(set2)
set1. intersection(set2)

score= int(input("Enter your score(0 to 7) ="))

if score > 7:
 print("Above average")
elif 4 <= score <= 7:
 print("Average: Good effort! Keep practicing, there's room for improvement.")
else:
 print("Below Average")
# Out:
# [24, 25, 27, 28, 29]
# ['Ram', 'Rita', 'Ragavi', 'Joshua']
# ['Ram', 'Rita', 'Ragavi', 'Joshua', 'Yazhini']
# [24, 25, 27, 28, 29]
# [24, 25, 26, 27, 28, 29]
# ['Ram', 'Rita', 'Ragavi', 'Joshua']
# ['Ram', 'Rita', 'Ragavi']
# [24, 25, 26, 27, 28, 29, 31, 30, 32]
# 32
# 24
# 252
# Ram
# Ragavi
# ['Ragavi']
# ['Ragavi', 'Rita', 'Ram']
# {'Ram': 80, 'Vijay': 68, 'Rohit': 76, 'John': 79, 'Gracy': 51}
# 68
# {'Ram': 80, 'Vijay': 68, 'Rohit': 76, 'John': 79, 'Gracy': 51, 'Janani': 80}
# {'Ram': 80, 'Vijay': 68, 'Rohit': 78, 'John': 79, 'Gracy': 51, 'Janani': 80}
# {1, 3, 5, 7, 9}
# {2, 3, 5, 8, 10}
# Enter your score(0 to 7) = 7
# Average: Good effort! Keep practicing, there's room for improvement.
